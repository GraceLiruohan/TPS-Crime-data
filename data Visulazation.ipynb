# %%
import pandas as pd
import os.path as osp
from os.path import curdir
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
df = pd.read_excel('master_data.xlsx',sheet_name='Break_and_Enter_Open_Data_Comb')

# %%
# define path and set up dataframe
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataframe from a CSV file or any other source
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

# Select the dependent variable
dependent_variable = 'dependent_variable_name'

# Select the independent variables
independent_variables = ['independent_variable1', 'independent_variable2', 'independent_variable3']

# Calculate the correlation coefficient for each independent variable
correlations = {}
for independent_variable in independent_variables:
    correlation_coefficient = df[independent_variable].corr(df[dependent_variable])
    correlations[independent_variable] = correlation_coefficient

# Plot the correlation for each independent variable
for independent_variable, correlation_coefficient in correlations.items():
    plt.scatter(df[independent_variable], df[dependent_variable])
    plt.title('Correlation between {} and {}'.format(independent_variable, dependent_variable))
    plt.xlabel(independent_variable)
    plt.ylabel(dependent_variable)
    plt.text(df[independent_variable].min(), df[dependent_variable].max(), 'Correlation: {:.2f}'.format(correlation_coefficient), ha='left')
    plt.show()

# %%
df.head()
# Out:
#            X          Y  OBJECTID EVENT_UNIQUE_ID             REPORT_DATE  \
# 0 -79.350229  43.646293         1  GO-20141260701  2014/01/01 05:00:00+00
# 1 -79.281075  43.765796         2  GO-20141260233  2014/01/01 05:00:00+00
# 2 -79.174033  43.761393         3  GO-20141260831  2014/01/01 05:00:00+00
# 3 -79.413387  43.650800         4  GO-20141260521  2014/01/01 05:00:00+00
# 4 -79.421673  43.792324         5  GO-20141261478  2014/01/01 05:00:00+00
#
#                  OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  \
# 0  2014/01/01 05:00:00+00         2014      January           1           1
# 1  2014/01/01 05:00:00+00         2014      January           1           1
# 2  2014/01/01 05:00:00+00         2014      January           1           1
# 3  2014/01/01 05:00:00+00         2014      January           1           1
# 4  2014/01/01 05:00:00+00         2014      January           1           1
#
# ...

# %% [markdown]
# Correlation Plot

# %%
df = pd.get_dummies(df, columns=['PREMISES_TYPE'],drop_first=True)

# %%
df.corr()
# Out:
#                                  X         Y  OBJECTID  REPORT_YEAR  \
# X                         1.000000  0.984169 -0.036631    -0.037115
# Y                         0.984169  1.000000 -0.030603    -0.031371
# OBJECTID                 -0.036631 -0.030603  1.000000     0.993045
# REPORT_YEAR              -0.037115 -0.031371  0.993045     1.000000
# REPORT_DAY                0.006172  0.006517  0.015954     0.005243
# REPORT_DOY                0.006119  0.008774  0.092856    -0.018635
# REPORT_HOUR               0.010488  0.004750 -0.082057    -0.082475
# OCC_YEAR                 -0.036525 -0.030851  0.990819     0.997049
# OCC_DAY                   0.006782  0.007494  0.001865    -0.006361
# OCC_DOY                   0.002745  0.005517  0.086512    -0.019122
# OCC_HOUR                 -0.001690 -0.002112 -0.078735    -0.078739
# UCR_CODE                  0.001097  0.001381  0.004952     0.004801
# UCR_EXT                   0.006791  0.003822 -0.035738    -0.034526
# ...

# %%
# Plot
plt.figure(figsize=(12,10), dpi= 80)
#sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)
sns.heatmap(df.corr(), cmap='PuBuGn', annot=True, linewidths = .001);

# Decorations
plt.title('Correlation Plot', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
indicator_group = df.groupby('OFFENCE')
crime_by_indicator = indicator_group.size().reset_index(name='n')
crime_by_indicator = crime_by_indicator.sort_values('n', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='n', y='OFFENCE', data=crime_by_indicator, orient='h')
for index, row in crime_by_indicator.iterrows():
    plt.text(row['n'], index, row['n'], color='black', ha="right", fontsize=8, va='center')
plt.xlabel('Number of Occurrences')
plt.ylabel('Type of Offence')
plt.title('Type of B&E', fontsize=16)
plt.tight_layout()
plt.show()

# %%
location_group = df.groupby('NEIGHBOURHOOD_140')
crime_by_location = location_group.size().reset_index(name='n')
crime_by_location = crime_by_location.sort_values('n', ascending=False)
crime_by_location_top10 = crime_by_location.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='n', y='NEIGHBOURHOOD_140', data=crime_by_location_top10, orient='h')
#for index, row in crime_by_location_top10.iterrows():
#    plt.text(row['n'], index, row['n'], color='black', ha="right", fontsize=8, va='center')
plt.xlabel('Number of Occurrences')
plt.ylabel('Neighbourhoods')
plt.title('Neighbourhoods with Most Crimes - Top 10', fontsize=16)
plt.tight_layout()
plt.show()

# %%
offence_location_group = df.groupby(['NEIGHBOURHOOD_140'])
offence_type_by_location = offence_location_group.size().reset_index(name='n')
offence_type_by_location = offence_type_by_location.sort_values('n', ascending=False)
offence_type_by_location_top10 = offence_type_by_location.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='NEIGHBOURHOOD_140', y='n', data=offence_type_by_location_top10, dodge=True)
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Occurrence')
plt.title('B&E vs. Neighbourhood Toronto', fontsize=16)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('Break_and_Enter_Open_Data.csv')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

indicator_group = df.groupby('PREMISES_TYPE')
crime_by_indicator = indicator_group.size().reset_index(name='n')
crime_by_indicator = crime_by_indicator.sort_values('n', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='n', y='PREMISES_TYPE', data=crime_by_indicator, orient='h')
#for index, row in crime_by_indicator.iterrows():
#    plt.text(row['n'], index, row['n'], color='black',ha="left", fontsize=10, va='top')
plt.xlabel('Number of Occurrences')
plt.ylabel('Type of Premises')
plt.title('Type of B&E by Premises', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

offence_location_group = df.groupby(['NEIGHBOURHOOD_140','PREMISES_TYPE'])
offence_type_by_location = offence_location_group.size().reset_index(name='n')
offence_type_by_location = offence_type_by_location.sort_values('n', ascending=False)
offence_type_by_location_top20 = offence_type_by_location.head(20)

plt.figure(figsize=(12, 6))
sns.barplot(x='NEIGHBOURHOOD_140', y='n',hue='PREMISES_TYPE', data=offence_type_by_location_top20, dodge=True)
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Occurrence')
plt.title('B&E vs. Neighbourhood Toronto', fontsize=16)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Crime per different hours

# %%
df = pd.read_csv('Break_and_Enter_Open_Data.csv')
offence_division_group = df.groupby(['DIVISION'])
offence_type_by_division = offence_division_group.size().reset_index(name='n')
offence_type_by_division = offence_type_by_division.sort_values('n', ascending=False)
offence_type_by_division_top10 = offence_type_by_division.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='DIVISION', y='n', data=offence_type_by_division_top10, dodge=True)
plt.xlabel('Division')
plt.ylabel('Number of Occurrence')
plt.title('B&E vs. Division Toronto', fontsize=16)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
hour_group = df.groupby('OCC_HOUR')
crime_hour = hour_group.size().reset_index(name='n')

plt.figure(figsize=(10, 6))
sns.lineplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', linewidth=2.5, alpha=0.7)
sns.scatterplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', s=5)
plt.title('Total Crimes by Hour of Day in Toronto', fontsize=16)
plt.xlabel('Hour (24-hour clock)', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by hour and division
hour_division_group = df.groupby(['OCC_HOUR', 'DIVISION'])
crime_hour_division = hour_division_group.size().reset_index(name='n')

# Plot the total crimes by hour
plt.figure(figsize=(10, 6))

# Plot the different divisions as separate lines
divisions = crime_hour_division['DIVISION'].unique()
for division in divisions:
    division_data = crime_hour_division[crime_hour_division['DIVISION'] == division]
    sns.lineplot(x='OCC_HOUR', y='n', data=division_data, linewidth=2.5, alpha=0.7, label=division)

plt.title('Total Crimes by Hour of Day in Toronto', fontsize=16)
plt.xlabel('Hour (24-hour clock)', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')

# Adjust the position of the legend
plt.legend(title='Division', bbox_to_anchor=(1, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Read the CSV file
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

# Group the data by day of the week
day_group = df.groupby('OCC_DOW')
crime_day = day_group.size().reset_index(name='n')

# Define the order of days of the week
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Convert 'OCC_DOW' column to categorical with specified order
crime_day['OCC_DOW'] = pd.Categorical(crime_day['OCC_DOW'], categories=day_order, ordered=True)

# Sort the data by 'OCC_DOW'
crime_day = crime_day.sort_values('OCC_DOW')

plt.figure(figsize=(10, 6))
sns.lineplot(x='OCC_DOW', y='n', data=crime_day, color='mediumseagreen', linewidth=2.5, alpha=0.7)
sns.scatterplot(x='OCC_DOW', y='n', data=crime_day, color='mediumseagreen', s=5)
plt.title('Total Crimes by Day in Toronto', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Read the CSV file
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

# Group the data by day of the week
month_group = df.groupby('OCC_MONTH')
crime_month = month_group.size().reset_index(name='n')

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
               'August', 'September', 'October', 'November', 'December']

# Convert 'OCC_DOW' column to categorical with specified order
crime_month['OCC_MONTH'] = pd.Categorical(crime_month['OCC_MONTH'], categories=month_order, ordered=True)

# Sort the data by 'OCC_DOW'
crime_month = crime_month.sort_values('OCC_MONTH')

plt.figure(figsize=(10, 6))
sns.lineplot(x='OCC_MONTH', y='n', data=crime_month, color='mediumseagreen', linewidth=2.5, alpha=0.7)
sns.scatterplot(x='OCC_MONTH', y='n', data=crime_month, color='mediumseagreen', s=5)
plt.title('Total Crimes by Month in Toronto', fontsize=16)
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Group the data by hour and division
hour_division_group = df.groupby(['OCC_HOUR', 'DIVISION'])
crime_hour_division = hour_division_group.size().reset_index(name='n')

# Filter for the sum of divisions D54 and D55
filtered_data = crime_hour_division[crime_hour_division['DIVISION'].isin(['D54_55'])]
filtered_data = filtered_data.groupby('OCC_HOUR')['n'].sum().reset_index()

# Plot the total crimes by hour
plt.figure(figsize=(10, 6))
#sns.lineplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', linewidth=2.5, alpha=0.7)
#sns.scatterplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', s=5)

# Plot the filtered divisions as a line
sns.lineplot(x='OCC_HOUR', y='n', data=filtered_data, linewidth=2.5, alpha=0.7, label='D54 + D55')

plt.title('Total Crimes (D54_55) by Hour of Day in Toronto', fontsize=16)
plt.xlabel('Hour (24-hour clock)', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.legend(title='Division')
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by month and division
month_division_group = df.groupby(['OCC_MONTH', 'DIVISION'])
crime_month_division = month_division_group.size().reset_index(name='n')

# Filter for the sum of divisions D54 and D55
filtered_data = crime_month_division[crime_month_division['DIVISION'].isin(['D54_55'])]
filtered_data = filtered_data.groupby('OCC_MONTH')['n'].sum().reset_index()

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
               'August', 'September', 'October', 'November', 'December']

# Convert 'OCC_MONTH' column to categorical with specified order
filtered_data['OCC_MONTH'] = pd.Categorical(filtered_data['OCC_MONTH'], categories=month_order, ordered=True)

# Sort the data by 'OCC_MONTH'
filtered_data = filtered_data.sort_values('OCC_MONTH')

# Plot the total crimes by month
plt.figure(figsize=(10, 6))
sns.lineplot(x='OCC_MONTH', y='n', data=filtered_data, linewidth=2.5, alpha=0.7, label='D54 + D55')

plt.title('Total (D54_55) Crimes by Month in Toronto', fontsize=16)
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.legend(title='Division')
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by day of the week and division
day_division_group = df.groupby(['OCC_DOW', 'DIVISION'])
crime_day_division = day_division_group.size().reset_index(name='n')

# Filter for the sum of divisions D54 and D55
filtered_data = crime_day_division[crime_day_division['DIVISION'].isin(['D54_55'])]
filtered_data = filtered_data.groupby('OCC_DOW')['n'].sum().reset_index()

# Define the order of days of the week
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']

# Convert 'OCC_DOW' column to categorical with specified order
filtered_data['OCC_DOW'] = pd.Categorical(filtered_data['OCC_DOW'], categories=day_order, ordered=True)

# Sort the data by 'OCC_DOW'
filtered_data = filtered_data.sort_values('OCC_DOW')

# Plot the total crimes by day of the week
plt.figure(figsize=(10, 6))
sns.lineplot(x='OCC_DOW', y='n', data=filtered_data, linewidth=2.5, alpha=0.7, label='D54 + D55')

plt.title('Total Crimes (D54_55) by Day of the Week in Toronto', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.legend(title='Division')
plt.tight_layout()
plt.show()

# %%
# Group the data by hour and division
hour_division_group = df.groupby(['OCC_DOW', 'DIVISION'])
crime_hour_division = hour_division_group.size().reset_index(name='n')

# Filter for the sum of divisions D54 and D55
filtered_data = crime_hour_division[crime_hour_division['DIVISION'].isin(['D54', 'D55'])]
filtered_data = filtered_data.groupby('OCC_DOW')['n'].sum().reset_index()

weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Plot the total crimes by hour
plt.figure(figsize=(10, 6))
#sns.lineplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', linewidth=2.5, alpha=0.7)
#sns.scatterplot(x='OCC_HOUR', y='n', data=crime_hour, color='mediumseagreen', s=5)

# Plot the filtered divisions as a line
sns.barplot(x='OCC_DOW', y='n', data=filtered_data, linewidth=2.5, alpha=0.7, label='D54 + D55')

plt.title('Total Crimes by DOW in Toronto', fontsize=16)
plt.xlabel('Weekday', fontsize=12, fontweight='bold')
plt.ylabel('Number of Occurrences', fontsize=12, fontweight='bold')
plt.legend(title='Division')
plt.tight_layout()
plt.show()

# %% [markdown]
# Crime per Neighbourhood

# %% [markdown]
# Crime per Division

# %% [markdown]
# Scatterplot: Bivariate Analysis

# %% [markdown]
# Time Series of B&E over time

# %%
# define path and set up dataframe
df = pd.read_csv('Break_and_Enter_Open_Data.csv')

# %%
df['New_Date_Column'] = pd.to_datetime(df['REPORT_DATE']).dt.strftime('%Y/%m/%d').str[:10]
df['New_Date_Column'] = pd.to_datetime(df['New_Date_Column'])
df.set_index('New_Date_Column', inplace=True)

# %%
# Count the number of crimes for each date
daily_crime_counts = df.resample('m').size()

# Plotting the time series
plt.figure(figsize=(10, 6))
daily_crime_counts.plot()
plt.title('Number of B&E Reported by Date')
plt.xlabel('Year')
plt.ylabel('Number of B&E')
plt.show()

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd
# Read the Excel file and collate the coordinates
df = pd.read_excel('Break_and_Enter_Open_Data.xlsx')  # Replace 'coordinates.xlsx' with your actual file path
#df['Coordinates'] = df.apply(lambda row: (row['X'], row['Y']), axis=1)
lat = df['Y'].tolist()
lng = df['X'].tolist()

# Create a base map centered on Toronto
map = folium.Map(location=[43.651070, -79.347015], zoom_start=12)

# Add a heat map layer to the map
HeatMap(list(zip(lat,lng))).add_to(map)

# Display the map
map.save("crime_heatmap.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # ADDITIONAL PLOTS

# %%
import pandas as pd
import os.path as osp
from os.path import curdir
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('Top 30 NB.xlsx',sheet_name='Division information')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               128 non-null    int64
#  1   Division2          128 non-null    object
#  2   Population         128 non-null    int64
#  3   # Crime_cleared    128 non-null    int64
#  4   #Crime             128 non-null    int64
#  5   % Crime_clear      128 non-null    float64
#  6   Annual budget      128 non-null    int64
#  7   Number of police   128 non-null    int64
#  8   Budget_per_police  128 non-null    float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 9.1+ KB

# %%
df
# Out:
#      Year Division2  Population  # Crime_cleared  #Crime  % Crime_clear  \
# 0    2014       D11      212644               96     255           0.38
# 1    2014       D12      233111              103     226           0.46
# 2    2014       D13      196576               84     287           0.29
# 3    2014       D14      284345              198     521           0.38
# 4    2014       D22      213428              171     521           0.33
# ..    ...       ...         ...              ...     ...            ...
# 123  2021       D43      282552               94     239           0.39
# 124  2021       D51      243335              221     669           0.33
# 125  2021       D52      148602              114     365           0.31
# 126  2021       D53      242350               94     533           0.18
# 127  2021   D54_D55      276764              170     596           0.29
#
#      Annual budget  Number of police  Budget_per_police
# ...

# %%
# Plot
plt.figure(figsize=(12,10), dpi= 80)
#sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)
sns.heatmap(df.corr(), cmap='PuBuGn', annot=True, linewidths = .001);

# Decorations
plt.title('Correlation Plot', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with columns 'Year' and 'Police'
# Modify the code below according to your actual data structure

# Group data by year and calculate average number of police officers
grouped_data = df.groupby('Year')['% Crime_clear'].mean()

# Create a line chart
plt.plot(grouped_data.index, grouped_data.values, marker='o')

# Set chart title and labels
plt.title('Average % of Crime cleared by Year')
plt.xlabel('Year')
plt.ylabel('% of Crime cleared')

plt.ylim(0.1, 0.4)  # Adjust the minimum and maximum values according to your needs

# Display the values of the year on the x-axis
plt.xticks(grouped_data.index)
# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)


# Display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with columns 'Year', 'Division', and 'Police'
# Modify the code below according to your actual data structure

# Group data by year and division, and calculate average number of police officers
grouped_data = df.groupby(['Year', 'Division2'])['% Crime_clear'].mean()

# Reset the index to convert the grouped data to a DataFrame
grouped_data = grouped_data.reset_index()

# Create a line chart for each division
divisions = grouped_data['Division2'].unique()

for division in divisions:
    division_data = grouped_data[grouped_data['Division2'] == division]
    plt.plot(division_data['Year'], division_data['% Crime_clear'], marker='o', label=division)

# Set chart title and labels
plt.title('Average Number of Police Officers by Year and Division')
plt.xlabel('Year')
plt.ylabel('Average Number of Police Officers')

# Display a legend for the divisions
plt.legend()
# Adjust the position of the legend
plt.legend(title='Division', bbox_to_anchor=(1, 1), loc='upper left')

#plt.tight_layout()
# Display the chart
plt.show()

# %%
df['Budget_per_police']
# Out:
# 0      159289.974522
# 1      160378.161290
# 2      173920.296000
# 3      160724.115578
# 4      154821.545455
#            ...
# 123    180355.693548
# 124    168437.444954
# 125    190481.777143
# 126    165612.970803
# 127    162940.290323
# Name: Budget_per_police, Length: 128, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with columns 'Year' and 'Police'
# Modify the code below according to your actual data structure

# Group data by year and calculate average number of police officers
grouped_data = df.groupby('Year')['Budget_per_police'].mean()

# Create a line chart
plt.plot(grouped_data.index, grouped_data.values, marker='o')

# Set chart title and labels
plt.title('Budget per Officer by Year')
plt.xlabel('Year')
plt.ylabel('Average of Budget per Officer')

plt.ylim(140000, 200000)  # Adjust the minimum and maximum values according to your needs

# Display the values of the year on the x-axis
plt.xticks(grouped_data.index)

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)


# Display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with columns 'Year' and 'Police'
# Modify the code below according to your actual data structure

# Group data by year and calculate average number of police officers
grouped_data = df.groupby('Year')['Number of police'].mean()

# Create a line chart
plt.plot(grouped_data.index, grouped_data.values, marker='o')

# Set chart title and labels
plt.title('Total # of Police by Year')
plt.xlabel('Year')
plt.ylabel('# of Police')
# Display the values of the year on the x-axis
plt.xticks(grouped_data.index)

plt.ylim(130, 190)  # Adjust the minimum and maximum values according to your needs

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)


# Display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with columns 'Year', 'Division', and 'Police'
# Modify the code below according to your actual data structure

# Group data by year and division, and calculate average number of police officers
grouped_data = df.groupby(['Year', 'Division2'])['Number of police'].mean()

# Reset the index to convert the grouped data to a DataFrame
grouped_data = grouped_data.reset_index()

# Create a line chart for each division
divisions = grouped_data['Division2'].unique()

for division in divisions:
    division_data = grouped_data[grouped_data['Division2'] == division]
    plt.plot(division_data['Year'], division_data['Number of police'], marker='o', label=division)

# Set chart title and labels
plt.title('Average Number of Police Officers by Year and Division')
plt.xlabel('Year')
plt.ylabel('Average Number of Police Officers')

# Display a legend for the divisions
plt.legend()
# Adjust the position of the legend
plt.legend(title='Division', bbox_to_anchor=(1, 1), loc='upper left')

#plt.tight_layout()
# Display the chart
plt.show()
